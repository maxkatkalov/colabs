# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
fig, axs = plt.subplots(2, 2)  # Creates a 2x2 grid of plots (4 plots in total within one figure)
axs[0, 0].plot([1, 2, 3], [4, 5, 6])
axs[0, 1].plot([1, 2, 3], [6, 5, 4])

# %%
plt.plot([1, 2, 3], [4, 5, 6])

# %%
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax1
# Out:
# <Axes: >

# %%
fig

# %%
fig, axs = plt.subplots(2, 2)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
fig = plt.figure()  
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 3)
ax3 = fig.add_subplot(2, 2, 4)
ax3.plot(np.random.standard_normal(50).cumsum(), color='blue', linestyle="dashed")

# %%
ax3.plot(np.random.standard_normal(50), color='blue', linestyle="dashed")

# %%
fig

# %%
ax1.hist(np.random.standard_normal(100), bins=20, color="black", alpha=0.3)
# Out:
# (array([ 1.,  2.,  2.,  3., 10.,  4.,  8.,  6.,  2., 12.,  7.,  8.,  9.,
#          7.,  7.,  5.,  4.,  0.,  0.,  3.]),
#  array([-2.43506064, -2.18496747, -1.9348743 , -1.68478113, -1.43468796,
#         -1.18459479, -0.93450161, -0.68440844, -0.43431527, -0.1842221 ,
#          0.06587107,  0.31596424,  0.56605741,  0.81615058,  1.06624375,
#          1.31633692,  1.56643009,  1.81652326,  2.06661643,  2.3167096 ,
#          2.56680277]),
#  <BarContainer object of 20 artists>)

# %%
fig

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.standard_normal(30))

# %%
fig

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.standard_normal(500), bins=50,
                        color="black", alpha=0.5)
fig.subplots_adjust(wspace=0.1, hspace=0.1)

# %%
plt.plot([0, 1, 2, 3], [0, 1, 4, 9], label='quadratic')

# %%
plt.plot([0, 1, 4, 9], label='quadratic')

# %%
plt.plot?

# %%
fig = plt.figure()
ax = fig.add_subplot()
data = np.random.standard_normal(30).cumsum()
ax.plot(data, color="black", linestyle="dashed", marker="o")

# %%
data.max()
# Out:
# np.float64(4.816678840890339)

# %%
ax.get_ylim()
# Out:
# (np.float64(-1.296211746895109), np.float64(5.107768868880123))

# %%
import matplotlib.ticker as ticker

fig, ax = plt.subplots()
ax.plot(range(10))

# Set ticks at every 2 units on x-axis
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))

plt.show()

# %%
import matplotlib.ticker as ticker

fig, ax = plt.subplots()
ax.plot(range(10))

# Format ticks to show as percentages
ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0%}"))

plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(np.random.standard_normal(1000).cumsum())
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(["one", "two", "three", "four", 'last'], rotation=30, fontsize=8)

# %%
comp1 = np.random.standard_normal(200)
comp2 = 10 + 2 * np.random.standard_normal(200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.histplot(values, bins=100, color="black")
# Out:
# <Axes: ylabel='Count'>

# %%
values
# Out:
# 0       1.168378
# 1      -1.168568
# 2      -1.390455
# 3       0.545260
# 4       1.972014
#          ...
# 395     9.875940
# 396     8.889224
# 397    10.398163
# 398     7.967332
# 399    10.396090
# Length: 400, dtype: float64

# %%
fig, ax = plt.subplots()

data = pd.read_csv("pydata-book/examples/spx.csv", index_col=0, parse_dates=True)
spx = data["SPX"]

# %%
spx
# Out:
# Date
# 1990-02-01     328.79
# 1990-02-02     330.92
# 1990-02-05     331.85
# 1990-02-06     329.66
# 1990-02-07     333.75
#                ...
# 2011-10-10    1194.89
# 2011-10-11    1195.54
# 2011-10-12    1207.25
# 2011-10-13    1203.66
# 2011-10-14    1224.58
# Name: SPX, Length: 5472, dtype: float64

# %%
df = pd.DataFrame(np.random.standard_normal((10, 4)).cumsum(0), columns=["A", "B", "C", "D"], index=np.arange(0, 100, 10))

# %%
df
# Out:
#            A         B         C         D
# 0   0.698964  0.129642  0.915306 -0.203410
# 10  1.261482 -0.973945  0.969138 -0.811637
# 20 -0.491190 -1.214675  0.322583 -1.853793
# 30  1.026883 -1.082379 -1.107006 -2.191729
# 40  2.365649 -1.487383 -1.620352 -0.927129
# 50  2.229954 -2.171832 -1.953870 -1.839401
# 60  3.603512  1.249508 -1.804598 -1.969321
# 70  3.313133  0.971723 -2.562363 -1.725644
# 80  5.918705  0.208052 -2.012343 -0.512302
# 90  7.097485  0.594693 -3.134915 -1.172073

# %%
df.plot()
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(2, 1)

# %%
data = pd.Series(np.random.uniform(size=16), index=list("abcdefghijklmnop"))

# %%
data
# Out:
# a    0.837567
# b    0.429190
# c    0.698601
# d    0.672883
# e    0.990082
# f    0.365592
# g    0.988473
# h    0.481757
# i    0.561060
# j    0.686781
# k    0.949528
# l    0.621193
# m    0.416769
# n    0.335540
# o    0.682356
# p    0.081145
# dtype: float64

# %%
data.plot.bar(ax=axes[0], color="black", alpha=0.7)
# Out:
# <Axes: >

# %%
data.plot.barh(ax=axes[1], color="black", alpha=0.7)
# Out:
# <Axes: >

# %%
fig

# %%
df = pd.DataFrame(np.random.uniform(size=(6, 4)), index=["one", "two", "three", "four", "five", "six"], columns=pd.Index(["A", "B", "C", "D"], name="Genus"))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.833994  0.742404  0.212644  0.147745
# two    0.682064  0.588709  0.286966  0.656520
# three  0.726391  0.081410  0.634934  0.529322
# four   0.735854  0.355306  0.547318  0.691266
# five   0.569721  0.895522  0.331681  0.756983
# six    0.752736  0.280853  0.711013  0.798144

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
tips = pd.read_csv("pydata-book/examples/tips.csv")

# %%
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
party_counts = pd.crosstab(tips["day"], tips["size"])

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_counts.reindex(index=["Thur", "Fri", "Sat", "Sun"])

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Thur  1  48   4   5  1  3
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
party_sums = pd.crosstab(tips["day"], tips["size"], values=tips["total_bill"], aggfunc="sum")

# %%
party_sums
# Out:
# size      1       2       3       4      5      6
# day
# Fri    8.58  261.15   15.98   40.17    NaN    NaN
# Sat   10.32  892.37  459.17  388.39  28.15    NaN
# Sun     NaN  684.84  332.76  480.39  81.00  48.17
# Thur  10.07  727.53   76.64  149.75  41.19  91.15

# %%
party_counts = party_counts.loc[:, 2:5]

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
party_counts.div(party_counts.sum(axis="columns"), axis="index")
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
18 / 16
# Out:
# 1.125

# %%
party_counts.sum(axis="index")
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# dtype: int64

# %%
tips["tip_pct"] = tips["tip"] / (tips["total_bill"] - tips["tip"])

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips["tip_pct"].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
macro = pd.read_csv("pydata-book/examples/macrodata.csv")

# %%
macro
# Out:
#      year  quarter    realgdp  realcons   realinv  realgovt  realdpi      cpi  \
# 0    1959        1   2710.349    1707.4   286.898   470.045   1886.9   28.980
# 1    1959        2   2778.801    1733.7   310.859   481.301   1919.7   29.150
# 2    1959        3   2775.488    1751.8   289.226   491.260   1916.4   29.350
# 3    1959        4   2785.204    1753.7   299.356   484.052   1931.3   29.370
# 4    1960        1   2847.699    1770.5   331.722   462.199   1955.5   29.540
# ..    ...      ...        ...       ...       ...       ...      ...      ...
# 198  2008        3  13324.600    9267.7  1990.693   991.551   9838.3  216.889
# 199  2008        4  13141.920    9195.3  1857.661  1007.273   9920.4  212.174
# 200  2009        1  12925.410    9209.2  1558.494   996.287   9926.4  212.671
# 201  2009        2  12901.504    9189.0  1456.678  1023.528  10077.5  214.469
# 202  2009        3  12990.341    9256.0  1486.398  1044.088  10040.6  216.385
#
# ...

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig, axs = plt.subplots(2, 1)
fig.set_layout_engine("constrained")

n = len(tips["total_bill"]) 
num_bins_sturges = int(1 + np.log2(n))  # https://www.vedantu.com/question-answer/the-sturges-rule-for-determining-the-number-of-class-11-maths-cbse-5fb494704ad6c23c32da71f2

bills_ax = axs[0]
tip_ax = axs[1]

# visualize the distribution of total bills
bills_ax.set_title("Distribution of Total Bills and Tips")
bills_ax.set_xlabel("Total Bill ($)")
bills_ax.set_ylabel("Frequency")

bills_x_ticks = np.arange(0, tips["total_bill"].max() + 2, 2)
bills_y_ticks = np.arange(0, plt.gca().get_ylim()[1] + 5, 5)
bills_ax.set_xticks(bills_x_ticks)
bills_ax.set_yticks(bills_y_ticks)

bills_ax.hist(tips["total_bill"], bins=num_bins_sturges)

# visualize the distribution of tips
tip_ax.set_xlabel("Tip amount ($)")
tip_ax.set_ylabel("Frequency")

tip_x_ticks = np.arange(0, tips["tip"].max() + 0.1, 0.5)
tip_y_ticks = np.arange(0, plt.gca().get_ylim()[1] + 5, 5)
tip_ax.set_xticks(tip_x_ticks)
tip_ax.set_yticks(tip_y_ticks)

tip_ax.hist(tips["tip"], bins=num_bins_sturges)
# Out:
# (array([85., 76., 51., 20.,  7.,  3.,  0.,  2.]),
#  array([ 1.   ,  2.125,  3.25 ,  4.375,  5.5  ,  6.625,  7.75 ,  8.875,
#         10.   ]),
#  <BarContainer object of 8 artists>)

# %%
# Sales data by region
regions = ["North", "South", "East", "West"]
sales = [300, 450, 200, 500]

plt.bar(regions, sales, color="skyblue")
plt.title("Sales by Region")  # Title of the graph
plt.xlabel("Regions")  # X-axis label
plt.ylabel("Sales")  # Y-axis label
plt.show()
